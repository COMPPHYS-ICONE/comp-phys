# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm

def f(x,y,R = 10,a = 1.,b = 1.):
    ans = (a*(x**2))-(b*(y**2))-(R**2)
    return ans
    
fig = plt.figure()
ax = fig.add_subplot(111, projection ='3d')
x = y = np.linspace(-5,5,100)
xv, yv = np.meshgrid(x,y)
z = f(xv, yv)
#ax.plot_wireframe(xv, yv, z, rstride=10, cstride=10, linewidth = 1)
ax.plot_surface(xv, yv, z, rstride=1, cstride=1, cmap=cm.RdYlBu, linewidth = 0)
plt.show()

# %%
'''

find all the prime numbers between a and b


'''

import numpy as np

a = 4
b = 10

listy = np.arange(a,b+1)
print listy



for j in listy:
    first = np.arange(1,listy[j+1]+1)
    for i in first:
        if listy[j]%first[i] == 2:
            print listy[j],'is prime'
# Out:
# [ 4  5  6  7  8  9 10]
# 8 is prime
# 8 is prime
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-4131af15e598> in <module>()
#      12     first = np.arange(1,listy[j+1]+1)
#      13     for i in first:
# ---> 14         if listy[j]%first[i] == 2:
#      15             print listy[j],'is prime'
#      16
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
'''
>>> temp_conv(0)
32.0

>>> temp_conv(117)
242.6



'''



def temp_conv(c):
    f = (9.0/5)*c + 32
    return f

if __name__ == "__main__":
    import doctest
